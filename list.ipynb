# %%
lst=[10,20,30,40,50];
lst.append(30)
lst.insert(15,26)
lst.extend([60,70])
lst.remove(40)
lst.pop()
print("index of 30:",lst.index(30))
print("count of 20:",lst.index(20))
lst.reverse()
copy_lst=lst.copy()
lst.clear()
print("copied lst:",copy_lst);
print("after cleared lst:" ,lst.clear());
# Out:
# index of 30: 2
# count of 20: 1
# copied lst: [60, 26, 30, 50, 30, 20, 10]
# after cleared lst: None
