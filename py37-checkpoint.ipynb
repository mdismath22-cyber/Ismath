# %%
customer_name =(input("enter customer name: "))
selling_price = float(input("Enter selling price: "))
product_name=(input("enter a product name: "))
Selling_price = float(input("Enter selling price: "))
Product_name=(input("enter a product name: "))
selling_Price = float(input("Enter selling price: "))
product_Name=(input("enter a product name: "))
gst_rate = float(input("Enter GST rate (%): "))
cgst = (selling_price * gst_rate) / 200
sgst = (selling_price * gst_rate) / 200
Total_tax = cgst + sgst
cgst = (Selling_price * gst_rate) / 200
sgst = (Selling_price * gst_rate) / 200
ToTal_tax = cgst + sgst
cgst = (selling_Price * gst_rate) / 200
sgst = (selling_Price * gst_rate) / 200
Total_Tax = cgst + sgst
total_tax=Total_tax + ToTal_tax + Total_Tax
total_amount = selling_price + Selling_price + selling_Price + total_tax
print("\n-------------Invoice-------------")
print(f"MALL Name:PHOENIX MALL")
print(f"CUSTOMER NAME:{customer_name}")
print(f"Item Name1: {product_name}")
print(f"Price1: ₹{selling_price}")
print(f"Item Name2: {Product_name}")
print(f"Price2: ₹{Selling_price}")
print(f"Item Name3: {product_Name}")
print(f"Price3: ₹{selling_Price}")
print(f"GST Rate: {gst_rate}%")
print(f"CGST ({gst_rate/2}%): ₹{cgst:.2f}")
print(f"SGST ({gst_rate/2}%): ₹{sgst:.2f}")
print(f"Total Amount: ₹{total_amount:.2f}")
# Out:
# enter customer name:  Jaliz
# Enter selling price:  1000
# enter a product name:  fan
# Enter selling price:  40
# enter a product name:  salt
# Enter selling price:  2500
# enter a product name:  rice
# Enter GST rate (%):  10
# -------------Invoice-------------
# MALL Name:PHOENIX MALL
# CUSTOMER NAME:Jaliz
# Item Name1: fan
# Price1: ₹1000.0
# Item Name2: salt
# Price2: ₹40.0
# Item Name3: rice
# Price3: ₹2500.0
# GST Rate: 10.0%
# CGST (5.0%): ₹125.00
# SGST (5.0%): ₹125.00
# Total Amount: ₹3894.00

# %%
n=int(input("enter n"))
i=1
fact=1
while(i<=n):
    fact=fact*i
    i=i+1
print(fact)
# Out:
# enter n 5
# 120

# %%
n=int(input("enter n"))
sum=0
while(n>0):
    a=n%10
    sum=sum+a
    n=n//10
print(sum)
# Out:
# enter n 123
# 6
