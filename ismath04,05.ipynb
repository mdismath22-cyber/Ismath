# %%
S=input("Enter a String:")
rev=S[::-1]
print("Reversed String :",rev)
# Out:
# Enter a String: ismath
# Reversed String : htamsi

# %%
n=int (input ("Enter a number:"))
for i in range (1,11):
    print(f"{n}*{i}={n*i}")
# Out:
# Enter a number: 24
# 24*1=24
# 24*2=48
# 24*3=72
# 24*4=96
# 24*5=120
# 24*6=144
# 24*7=168
# 24*8=192
# 24*9=216
# 24*10=240

# %%
n=int(input("subjects:"))
total_gp =0
total_marks =0
for i in range(n):
    m = int (input("marks: "))
    total_marks += m
    if m>= 90: gp= 10
    elif m>= 80: gp= 9
    elif m>= 70: gp= 8
    elif m>= 60: gp= 7
    elif m>= 50: gp= 6
    else : gp= 0
    total_gp +=gp
    gpa = total_gp / n
    print("Total Marks:",total_marks)
    print("GPA / CGPA:", round(gpa,2))
# Out:
# subjects: 6
# marks:  85
# Total Marks: 85
# GPA / CGPA: 1.5
# marks:  95
# Total Marks: 180
# GPA / CGPA: 3.17
# marks:  87
# Total Marks: 267
# GPA / CGPA: 4.67
# marks:  76
# Total Marks: 343
# GPA / CGPA: 6.0
# marks:  98
# Total Marks: 441
# GPA / CGPA: 7.67
# marks:  76
# Total Marks: 517
# GPA / CGPA: 9.0
